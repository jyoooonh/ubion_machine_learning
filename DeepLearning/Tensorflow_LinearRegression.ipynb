# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# 가상적인 데이터 생성
X = data = np.linspace(1, 2, 200)		# 시작값 = 1, 종료값 = 2, 개수 = 200
y = X * 4 + np.random.randn(200) * 0.3		# x를 4배로 하고 편차 0.3정도의 가우시안 잡은 추가
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(1, input_dim = 1, activation='linear'))
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
model.fit(X, y, batch_size=1, epochs=30)

predict = model.predict(data)

plt.plot(data, predict, 'b', data, y, 'k.')		# 첫 번째 그래프는 파란색 마커로
plt.show()
# 두 번째 그래프는 검정색으로 그린다.
# Out:
# Epoch 1/30
# 200/200 [==============================] - 0s 341us/step - loss: 0.7194 - mse: 0.7194
# Epoch 2/30
# 200/200 [==============================] - 0s 304us/step - loss: 0.1506 - mse: 0.1506
# Epoch 3/30
# 200/200 [==============================] - 0s 309us/step - loss: 0.1407 - mse: 0.1407
# Epoch 4/30
# 200/200 [==============================] - 0s 317us/step - loss: 0.1331 - mse: 0.1331
# Epoch 5/30
# 200/200 [==============================] - 0s 316us/step - loss: 0.1235 - mse: 0.1235
# Epoch 6/30
# 200/200 [==============================] - 0s 319us/step - loss: 0.1194 - mse: 0.1194
# Epoch 7/30
# 200/200 [==============================] - 0s 307us/step - loss: 0.1162 - mse: 0.1162
# Epoch 8/30
# 200/200 [==============================] - 0s 307us/step - loss: 0.1104 - mse: 0.1104
# Epoch 9/30
# 200/200 [==============================] - 0s 310us/step - loss: 0.1087 - mse: 0.1087
# Epoch 10/30
# 200/200 [==============================] - 0s 326us/step - loss: 0.1063 - mse: 0.1063
# Epoch 11/30
# 200/200 [==============================] - 0s 326us/step - loss: 0.1030 - mse: 0.1030
# Epoch 12/30
# 200/200 [==============================] - 0s 342us/step - loss: 0.1032 - mse: 0.1032
# Epoch 13/30
# 200/200 [==============================] - 0s 316us/step - loss: 0.0998 - mse: 0.0998
# Epoch 14/30
# 200/200 [==============================] - 0s 315us/step - loss: 0.0997 - mse: 0.0997
# Epoch 15/30
# 200/200 [==============================] - 0s 470us/step - loss: 0.0990 - mse: 0.0990
# Epoch 16/30
# 200/200 [==============================] - 0s 303us/step - loss: 0.0983 - mse: 0.0983
# Epoch 17/30
# 200/200 [==============================] - 0s 304us/step - loss: 0.0995 - mse: 0.0995
# Epoch 18/30
# 200/200 [==============================] - 0s 313us/step - loss: 0.0985 - mse: 0.0985
# Epoch 19/30
# 200/200 [==============================] - 0s 339us/step - loss: 0.0966 - mse: 0.0966
# Epoch 20/30
# 200/200 [==============================] - 0s 321us/step - loss: 0.0957 - mse: 0.0957
# Epoch 21/30
# 200/200 [==============================] - 0s 320us/step - loss: 0.0978 - mse: 0.0978
# Epoch 22/30
# 200/200 [==============================] - 0s 321us/step - loss: 0.0959 - mse: 0.0959
# Epoch 23/30
# 200/200 [==============================] - 0s 313us/step - loss: 0.0918 - mse: 0.0918
# Epoch 24/30
# 200/200 [==============================] - 0s 308us/step - loss: 0.0983 - mse: 0.0983
# Epoch 25/30
# 200/200 [==============================] - 0s 302us/step - loss: 0.0968 - mse: 0.0968
# Epoch 26/30
# 200/200 [==============================] - 0s 310us/step - loss: 0.0966 - mse: 0.0966
# Epoch 27/30
# 200/200 [==============================] - 0s 305us/step - loss: 0.0967 - mse: 0.0967
# Epoch 28/30
# 200/200 [==============================] - 0s 303us/step - loss: 0.0964 - mse: 0.0964
# Epoch 29/30
# 200/200 [==============================] - 0s 307us/step - loss: 0.0969 - mse: 0.0969
# Epoch 30/30
# 200/200 [==============================] - 0s 305us/step - loss: 0.0965 - mse: 0.0965
# 7/7 [==============================] - 0s 499us/step
